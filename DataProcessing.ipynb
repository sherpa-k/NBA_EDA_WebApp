# %% [markdown]
# # NBA Data Collection

# %%
import re
import os
import json
import pandas as pd
import numpy as np
import time
import requests
from bs4 import BeautifulSoup
from nba_api.stats.endpoints import leaguedashteamstats, leaguedashplayerstats, leaguestandingsv3, shotchartdetail

# %% [markdown]
# ### Retrieving NBA.com Data

# %% [markdown]
# Import player and team stats for this season from NBA.com

# %%
player_stats = leaguedashplayerstats.LeagueDashPlayerStats().get_data_frames()[0]
team_stats = leaguedashteamstats.LeagueDashTeamStats().get_data_frames()[0]
standings = leaguestandingsv3.LeagueStandingsV3(season_type='Regular Season').get_data_frames()[0]

# %%
# Add points rebounds and assists per game as a feature
team_stats['PPG'] = team_stats['PTS']/team_stats['GP']
team_stats['APG'] = team_stats['AST']/team_stats['GP']
team_stats['RPG'] = team_stats['REB']/team_stats['GP']

player_stats['PPG'] = player_stats['PTS']/player_stats['GP']
player_stats['APG'] = player_stats['AST']/player_stats['GP']
player_stats['RPG'] = player_stats['REB']/player_stats['GP']

# %%
# Add TEAM_NAME in standings
standings['TEAM_NAME'] = standings[['TeamCity', 'TeamName']].apply(lambda x: ' '.join(x), axis=1)

# %% [markdown]
# ### Retrieving NBA Advanced stats from Basketball Reference

# %%
data = requests.get("https://www.basketball-reference.com/leagues/NBA_2023.html").text
soup = BeautifulSoup(data, 'html.parser')

table = soup.find('table', {'id':'advanced-team'})

# %%
headers = []
header = table.thead.find_all('tr')[1]
for th in header.find_all('th'):
    headers.append(th.get_text())
    
headers = headers[1:14]
headers
# Out:
# ['Team',
#  'Age',
#  'W',
#  'L',
#  'PW',
#  'PL',
#  'MOV',
#  'SOS',
#  'SRS',
#  'ORtg',
#  'DRtg',
#  'NRtg',
#  'Pace']

# %%
dat  = []
for row in table.tbody.find_all('tr'):
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    dat.append([ele for ele in cols if ele])

# %%
data =[]
for x in dat:
    data.append(x[0:13])
    
advanced_stats = pd.DataFrame(data, columns=headers)

# %%
advanced_stats['Orank'] = pd.to_numeric(advanced_stats['ORtg']).rank(method='min', ascending=False).astype(int)
advanced_stats['Drank'] = pd.to_numeric(advanced_stats['DRtg']).rank(method='min').astype(int)
advanced_stats['Nrank'] = advanced_stats.index.astype(int) + 1
advanced_stats['PaceRank'] = pd.to_numeric(advanced_stats['Pace']).rank(method='min', ascending=False).astype(int)
advanced_stats
# Out:
#                        Team   Age   W   L  PW  PL     MOV    SOS    SRS  \
# 0           Boston Celtics*  27.4  57  25  57  25    6.52  -0.15   6.38
# 1      Cleveland Cavaliers*  25.4  51  31  55  27    5.38  -0.15   5.23
# 2       Philadelphia 76ers*  28.2  54  28  52  30    4.32   0.06   4.37
# 3        Memphis Grizzlies*  24.4  51  31  51  31    3.94  -0.34   3.60
# 4          Milwaukee Bucks*  29.8  58  24  50  32    3.63  -0.02   3.61
# 5           Denver Nuggets*  26.6  53  29  49  33    3.33  -0.29   3.04
# 6          New York Knicks*  24.5  47  35  48  34    2.93   0.06   2.99
# 20  113.0  113.3  -0.3   96.3     25      8     21        29
# 21  115.8  116.7  -0.9  100.5     10     23     22        10
# 22  114.4  115.6  -1.2   98.6     21     21     23        17
# 23  111.6  114.2  -2.6   99.3     26     14     24        13
# 24  114.6  117.7  -3.1  101.1     19     26     25         4
# 25  114.8  118.8  -4.0   98.6     18     27     26        17
# 26  109.2  115.3  -6.1  100.8     30     20     27         8
# 27  111.4  119.3  -7.9   99.0     27     29     28        15
# 28  110.7  118.9  -8.2   99.0     28     28     29        15
# 29  110.2  120.0  -9.8  101.6     29     30     30         1

# %%
# Fix team names
advanced_stats.replace("Los Angeles Clippers*", "LA Clippers", inplace=True)
team_names = [name.replace("*","") for name in advanced_stats['Team']]
advanced_stats['Team'] = team_names

# %%
team_stats['FG_PCT_RANK'] = team_stats['FG_PCT'].rank(method='min', ascending=False).astype(int)
team_stats['FG3_PCT_RANK'] = team_stats['FG3_PCT'].rank(method='min', ascending=False).astype(int)

# %% [markdown]
# ### Retrieving NBA Team Salaries from Basketball Reference

# %%
data = requests.get("https://www.basketball-reference.com/contracts/").text
soup = BeautifulSoup(data, 'html.parser')

table = soup.find('table', {'id':'team_summary'})

# %%
headers = []
header = table.thead.find_all('tr')[1]
for th in header.find_all('th'):
    headers.append(th.get_text())
headers = headers[1:8]

data = []
for row in table.tbody.find_all('tr'):
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

team_salaries = pd.DataFrame(data, columns=headers)
team_salaries
# Out:
#                       Team       2022-23       2023-24       2024-25  \
# 0     Los Angeles Clippers  $199,618,760  $201,872,990  $148,079,728
# 1    Golden State Warriors  $196,914,190  $211,685,897  $148,977,903
# 2          Milwaukee Bucks  $189,554,017  $156,679,413  $112,176,005
# 3           Boston Celtics  $188,309,002  $163,100,916  $120,909,897
# 4         Dallas Mavericks  $178,751,606  $108,671,031   $94,252,163
# 5             Phoenix Suns  $177,017,682  $165,602,967  $175,429,147
# 6       Los Angeles Lakers  $176,771,244  $127,212,036  $100,859,025
# 7           Denver Nuggets  $166,664,217  $168,687,600  $168,659,596
# 8            Brooklyn Nets  $165,325,654  $145,554,223   $86,592,682
# 9    Oklahoma City Thunder  $161,215,815   $99,032,051  $101,135,018
# 10      Philadelphia 76ers  $159,678,581  $164,159,456   $66,209,363
# 11         Toronto Raptors  $157,848,655  $144,104,331   $42,889,250
# 12      Washington Wizards  $156,335,482  $148,672,960   $80,695,778
# 13    New Orleans Pelicans  $156,249,429  $157,375,200  $129,942,505
# 14           Atlanta Hawks  $155,979,447  $169,265,314  $128,910,716
# 15     Cleveland Cavaliers  $155,863,322  $126,968,445  $117,588,652
# 16               Utah Jazz  $155,400,005   $93,702,683   $43,470,744
# 17           Chicago Bulls  $153,293,137  $122,259,970   $79,920,112
# 18              Miami Heat  $152,567,917  $173,127,647  $141,644,117
# 19         New York Knicks  $152,468,722  $164,306,088  $118,023,452
# 20  Minnesota Timberwolves  $151,360,728  $144,140,750   $97,629,325
# 21  Portland Trail Blazers  $148,610,431  $112,963,169  $116,220,313
# 22        Sacramento Kings  $144,158,560  $107,475,393   $79,816,114
# 23         Houston Rockets  $140,957,128   $68,984,207   $69,836,767
# 24          Indiana Pacers  $137,034,889   $95,252,116   $65,596,614
# 25           Orlando Magic  $136,633,986  $106,940,331   $59,725,976
# 26       Memphis Grizzlies  $134,351,866  $137,938,753  $126,434,316
# 27       Charlotte Hornets  $133,117,376   $88,247,936   $51,904,934
# 28         Detroit Pistons  $131,963,459   $97,490,229   $60,854,406
# 29       San Antonio Spurs  $106,960,542   $84,257,979   $45,562,240
#
#          2025-26      2026-27      2027-28
# 0    $20,482,758         None         None
# 1   $125,348,403  $65,464,286         None
# 2    $79,586,167         None         None
# 3    $71,995,974         None         None
# 4    $56,999,660  $48,967,380         None
# 5   $155,194,023  $57,124,200  $61,063,800
# 6           None         None         None
# 7   $124,856,778  $98,962,150  $61,908,000
# 8    $40,278,480         None         None
# 9    $92,388,970  $65,691,372         None
# 10   $54,404,000  $58,156,000         None
# 11          None         None         None
# 12   $76,986,270  $57,128,610         None
# 13   $77,234,375  $41,540,000  $44,220,000
# 14  $104,703,628  $73,878,094         None
# 15  $102,580,076  $41,540,000  $44,220,000
# 16   $30,237,463         None         None
# 17   $51,398,778  $48,967,380         None
# 18  $144,843,431  $33,000,000         None
# 19   $95,082,304  $29,616,071         None
# 20  $106,601,506  $57,124,200  $61,063,800
# 21  $121,516,797  $71,246,860     $268,032
# 22   $66,231,784         None         None
# 23   $40,653,257  $18,239,000         None
# 24   $11,375,024         None         None
# 25   $28,372,468         None         None
# 26   $90,933,288  $60,205,000  $44,220,000
# 27   $43,787,013         None         None
# 28   $16,590,307         None         None
# 29   $36,784,592  $17,500,000         None

# %% [markdown]
# Create .csv

# %%
team_stats.to_csv("Team-stats.csv")
player_stats.to_csv("Player_stats.csv")
standings.to_csv('Standings.csv')
advanced_stats.to_csv('advanced_stats.csv')
team_salaries.to_csv('team_salaries.csv')

# %% [raw]
# Get NBA team logos.

# %%
newdir = "logos/"
if not os.path.exists(newdir):
    os.makedirs(newdir)

# %%
good_names = [team.replace(" ", "-").lower() for team in team_stats['TEAM_NAME']]

# %%
for team in good_names:
    url = f"https://loodibee.com/nba/nba-{team}-logo/"
    try:
        logo = requests.get(url)
        soup = BeautifulSoup(logo.text, "html.parser")
    
        main = soup.find(id = "main")
        img = main.find('img')['src']

        img_data = requests.get(img).content
        team_name = team.replace("-", " ")
        with open(f'logos/{team_name}.png', "wb") as f: 
           f.write(img_data)
        
    except:
        continue

# %% [markdown]
# Manually Add logos Denver Nuggets

# %%
logo = requests.get("https://loodibee.com/nba/nba-denver-nuggets-logo-2018/")
soup = BeautifulSoup(logo.text, "html.parser")
    
main = soup.find(id = "main")
img = main.find('img')['src']

img_data = requests.get(img).content

with open('logos/Denver Nuggets.png', "wb") as f: 
    f.write(img_data)

# %% [markdown]
# Rename LA Clippers.png

# %%
os.rename("logos/la clippers.png", "logos/LA Clippers.png")
